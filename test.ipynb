# %%
import requests

url = "https://stocks.techglobetrading.com/stocks/range/AAPL/range/1/day/2023-01-01/2023-10-01"

payload = {}
headers = {
  'Authorization': 'WZRXIAM4HGSQ'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#   "adjusted": true,
#   "count": 187,
#   "queryCount": 187,
#   "request_id": "adc13004e2e4fb6838884a7aebbbfe3c",
#   "results": [
#     {
#       "c": 125.07,
#       "h": 130.9,
#       "l": 124.17,
#       "n": 1021065,
#       "o": 130.28,
#       "t": 1672722000000,
#       "v": 112117471.0,
#       "vw": 125.725
#     },
#     {
#       "c": 126.36,
#       "h": 128.6557,
#       "l": 125.08,
#       "n": 770042,
#       "o": 126.89,
#       "t": 1672808400000,
#       "v": 89100633.0,
#       "vw": 126.6464
#     },
#     {
#       "c": 125.02,
#       "h": 127.77,
#       "l": 124.76,
#       "n": 665458,
#       "o": 127.13,
#       "t": 1672894800000,
#       "v": 80716808.0,
#       "vw": 126.0883
#     },
#     {
#       "c": 129.62,
#       "h": 130.29,
#       "l": 124.89,
#       "n": 711520,
#       "o": 126.01,
#       "t": 1672981200000,
#       "v": 87754715.0,
#       "vw": 128.1982
#     },
#     {
#       "c": 130.15,
#       "h": 133.41,
# ...
